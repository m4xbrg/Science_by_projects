# %% [markdown]
# # Function Explorer — Milestone 3
# Adds:
# - **Domain** intervals via SymPy sets: `continuous_domain`
# - **Approximate range** via min/max over sampled points
# - **Reusable widget** with sliders for `x_min`, `x_max`, `samples` and a TextBox for the expression

# %%
from function_explorer_m3 import plot_with_domain, widget

# Static analysis + plot (returns metadata dictionary)
meta = plot_with_domain("sin(x)/x", x_min=-10, x_max=10, samples=1600)
print(meta)

# Interactive widget (adjust sliders/textbox and run this cell to open the UI)
widget("sin(x)/x", -10, 10, 1600)
# Out:
# {'expr_sympy': 'sin(x)/x', 'domain_intervals': [(None, None)], 'domain_intervals_clipped': [(-10, 10)], 'range_approx': (-0.21723255035485659, 0.9999934814504242), 'plot_window': (-10, 10)}
