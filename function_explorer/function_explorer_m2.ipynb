# %% [markdown]
# # Function Explorer — Milestone 2
# Adds:
# - Discontinuities via denominator zeros
# - Zeros with `solveset`
# - y-intercept (value or finite limit)
# - Vertical asymptotes (one-sided limit to ±∞ at denominator zeros)

# %%
from function_explorer_m2 import analyze_expression, plot_with_annotations

# Rational with removable discontinuity at x=1, vertical asymptote for other examples
print("Analysis ( (x**2-1)/(x-1) ):")
res1 = analyze_expression("(x**2-1)/(x-1)")
print(res1)
plot_with_annotations("(x**2-1)/(x-1)", x_min=-4, x_max=4, samples=1600)

print("Analysis ( 1/(x-2) ):")
res2 = analyze_expression("1/(x-2)")
print(res2)
plot_with_annotations("1/(x-2)", x_min=-4, x_max=6, samples=1600)

print("Analysis ( log(x) ):")
res3 = analyze_expression("log(x)")
print(res3)
plot_with_annotations("log(x)", x_min=-1, x_max=5, samples=1600)
# Out:
# Analysis ( (x**2-1)/(x-1) ):
# {'expr_str': '(x**2-1)/(x-1)', 'expr_sympy': '(x**2 - 1)/(x - 1)', 'denominator': 'x - 1', 'discontinuities': [], 'zeros': [], 'y_intercept': None, 'vertical_asymptotes': []}
# Analysis ( 1/(x-2) ):
# {'expr_str': '1/(x-2)', 'expr_sympy': '1/(x - 2)', 'denominator': 'x - 2', 'discontinuities': [], 'zeros': [], 'y_intercept': None, 'vertical_asymptotes': []}
# Analysis ( log(x) ):
# {'expr_str': 'log(x)', 'expr_sympy': 'log(x)', 'denominator': '1', 'discontinuities': [], 'zeros': [], 'y_intercept': None, 'vertical_asymptotes': []}
# <lambdifygenerated-3>:2: RuntimeWarning: invalid value encountered in log
#   return log(x)
# {'expr_str': 'log(x)',
#  'expr_sympy': 'log(x)',
#  'denominator': '1',
#  'discontinuities': [],
#  'zeros': [],
#  'y_intercept': None,
#  'vertical_asymptotes': []}
